# %% [markdown]
# # Data Preprocessing

# %%
import pandas as pd
import numpy as np
import warnings

pd.set_option('display.float_format', '{:.4f}'.format)
warnings.filterwarnings("ignore")

# %%
fhv_df = pd.read_csv("data/FHVHV_Trip_Data.csv", index_col=[0])
yellow_df = pd.read_csv("data/Yellow_Trip_Data.csv", index_col=[0])
green_df = pd.read_csv("data/Green_Trip_Data.csv", index_col=[0])

# %%
taxi_zones_df = pd.read_csv("data/Taxi_Zones_Data.csv")
taxi_zones_df.columns = taxi_zones_df.columns.str.lower()
taxi_zones_df.set_index("locationid", inplace=True)

# %%
taxi_zones_df.head()
# Out:
#                   borough                     zone service_zone
# locationid
# 1                     EWR           Newark Airport          EWR
# 2                  Queens              Jamaica Bay    Boro Zone
# 3                   Bronx  Allerton/Pelham Gardens    Boro Zone
# 4               Manhattan            Alphabet City  Yellow Zone
# 5           Staten Island            Arden Heights    Boro Zone

# %% [markdown]
# # For-Hire Dataset

# %%
fhv_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
fhv_df["hvfhs_license_num"].value_counts()
# Out:
# hvfhs_license_num
# HV0003    10521027
# HV0005     3908330
# HV0004       70643
# Name: count, dtype: int64

# %%
# Replace the business code with the name
fhv_df["hvfhs_license_num"] = fhv_df["hvfhs_license_num"].replace(to_replace=["HV0002", "HV0003", "HV0004", "HV0005"], value=["Juno", "Uber", "Via", "Lyft"])
fhv_df["hvfhs_license_num"].value_counts()
# Out:
# hvfhs_license_num
# Uber    10521027
# Lyft     3908330
# Via        70643
# Name: count, dtype: int64

# %%
# Filter to only Uber and Lyft
fhv_df = fhv_df[~(fhv_df["hvfhs_license_num"]=="Via")]
fhv_df.reset_index(drop=True, inplace=True)

# %%
# Columns not needed
bad_cols = ["dispatching_base_num", "originating_base_num"]
fhv_df.drop(columns=bad_cols, inplace=True)

# %%
# Columns with Null values
fhv_df.isna().any()
# Out:
# hvfhs_license_num       False
# request_datetime        False
# on_scene_datetime        True
# pickup_datetime         False
# dropoff_datetime        False
# pulocationid            False
# dolocationid            False
# trip_miles              False
# trip_time               False
# base_passenger_fare     False
# tolls                   False
# bcf                     False
# sales_tax               False
# congestion_surcharge    False
# airport_fee              True
# tips                    False
# driver_pay              False
# shared_request_flag     False
# shared_match_flag       False
# access_a_ride_flag      False
# wav_request_flag        False
# wav_match_flag          False
# dtype: bool

# %%
fhv_df["airport_fee"] = fhv_df["airport_fee"].replace(np.nan, 0.00)

# %%
# Pick up and drop off locations
pick_up_borough = fhv_df["pulocationid"].map(taxi_zones_df["borough"])
pick_up_zone = fhv_df["pulocationid"].map(taxi_zones_df["zone"])
drop_off_borough = fhv_df["dolocationid"].map(taxi_zones_df["borough"])
drop_off_zone = fhv_df["dolocationid"].map(taxi_zones_df["zone"])

# Put into the dataframe
fhv_df.insert(loc=7, column="pick_up_borough", value=pick_up_borough)
fhv_df.insert(loc=8, column="pick_up_zone", value=pick_up_zone)
fhv_df.insert(loc=9, column="drop_off_borough", value=drop_off_borough)
fhv_df.insert(loc=10, column="drop_off_zone", value=drop_off_zone)

# %%
fhv_df.drop(columns=["pulocationid", "dolocationid"], inplace=True)

# %%
# Fix a couple of column names
fhv_df.rename(columns={"hvfhs_license_num": "business", "bcf": "black_car_fund"}, inplace=True)

# %%
fhv_df.head()
# Out:
#   business     request_datetime    on_scene_datetime      pickup_datetime  \
# 0     Uber  2020-01-21 18:46:40  2020-01-21 18:47:21  2020-01-21 18:47:57
# 1     Uber  2020-01-17 19:27:42  2020-01-17 19:28:38  2020-01-17 19:29:55
# 2     Lyft  2020-01-18 11:57:57                  NaN  2020-01-18 12:00:50
# 3     Lyft  2020-01-13 19:27:35                  NaN  2020-01-13 19:31:23
# 4     Lyft  2020-01-24 03:56:08                  NaN  2020-01-24 03:59:28
#
#       dropoff_datetime pick_up_borough             pick_up_zone  \
# 0  2020-01-21 18:58:42       Manhattan  Two Bridges/Seward Park
# 1  2020-01-17 19:45:27       Manhattan             East Village
# 2  2020-01-18 12:08:26       Manhattan             Midtown East
# 3  2020-01-13 19:42:23       Manhattan     Central Harlem North
# 4  2020-01-24 04:11:37          Queens        LaGuardia Airport
#
#   drop_off_borough              drop_off_zone  trip_miles  ...  sales_tax  \
# 0         Brooklyn  Williamsburg (North Side)      2.5400  ...     1.1800
# 1        Manhattan                   Union Sq      1.6600  ...     1.1500
# 2        Manhattan            Lenox Hill West      1.3940  ...     0.6400
# 3            Bronx             West Concourse      1.6470  ...     0.6100
# 4           Queens                   Elmhurst      3.8590  ...     0.9100
#
#    congestion_surcharge  airport_fee   tips  driver_pay  shared_request_flag  \
# 0                2.7500       0.0000 3.0000      8.1100                    N
# 1                2.7500       0.0000 1.0000      9.5000                    N
# 2                2.7500       0.0000 0.0000      5.3900                    N
# 3                0.0000       0.0000 1.0000      7.2400                    N
# 4                0.0000       0.0000 1.0000     10.2400                    N
#
#    shared_match_flag  access_a_ride_flag  wav_request_flag wav_match_flag
# 0                  N                                     N              N
# 1                  N                                     N              N
# 2                  N                   N                 N              N
# 3                  N                   N                 N              N
# 4                  N                   N                 N              N
#
# [5 rows x 24 columns]

# %%
fhv_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14429357 entries, 0 to 14429356
# Data columns (total 24 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   business              object
#  1   request_datetime      object
#  2   on_scene_datetime     object
#  3   pickup_datetime       object
#  4   dropoff_datetime      object
#  5   pick_up_borough       object
#  6   pick_up_zone          object
#  7   drop_off_borough      object
#  8   drop_off_zone         object
#  9   trip_miles            float64
#  10  trip_time             int64
#  11  base_passenger_fare   float64
#  12  tolls                 float64
#  13  black_car_fund        float64
#  14  sales_tax             float64
#  15  congestion_surcharge  float64
#  16  airport_fee           float64
#  17  tips                  float64
#  18  driver_pay            float64
#  19  shared_request_flag   object
#  20  shared_match_flag     object
#  21  access_a_ride_flag    object
#  22  wav_request_flag      object
#  23  wav_match_flag        object
# dtypes: float64(9), int64(1), object(14)
# memory usage: 2.6+ GB

# %%
fhv_df.to_csv("data/FHVHV_Trip_Data_Clean.csv", index=False)

# %% [markdown]
# # Yellow Taxi Dataset

# %%
# Replace column names
cols_replace = {
    "tpep_pickup_datetime": "pickup_datetime", "tpep_dropoff_datetime": "dropoff_datetime",
    "trip_distance": "trip_miles", "tolls_amount":  "tolls", "tip_amount": "tips", "ratecodeid": "trip_category"
    }
yellow_df.rename(columns=cols_replace, inplace=True)

# %%
# Columns with Null values
yellow_df.isna().any()
# Out:
# vendorid                 False
# pickup_datetime          False
# dropoff_datetime         False
# passenger_count           True
# trip_miles               False
# trip_category             True
# store_and_fwd_flag        True
# pulocationid             False
# dolocationid             False
# payment_type             False
# fare_amount              False
# extra                    False
# mta_tax                  False
# tips                     False
# tolls                    False
# improvement_surcharge    False
# total_amount             False
# congestion_surcharge      True
# airport_fee               True
# dtype: bool

# %%
yellow_df["congestion_surcharge"] = yellow_df["congestion_surcharge"].replace(np.nan, 0.00)
yellow_df["airport_fee"] = yellow_df["airport_fee"].replace(np.nan, 0.00)

# %%
yellow_df["trip_category"].value_counts()
# Out:
# trip_category
# 1.0000     12494638
# 2.0000       391082
# 5.0000        81291
# 99.0000       53138
# 3.0000        32362
# 4.0000        20871
# 6.0000           73
# Name: count, dtype: int64

# %%
yellow_df["store_and_fwd_flag"].value_counts()
# Out:
# store_and_fwd_flag
# N    12944407
# Y      129048
# Name: count, dtype: int64

# %%
yellow_df["passenger_count"].value_counts()
# Out:
# passenger_count
# 1.0000    9802523
# 2.0000    1897912
# 3.0000     481916
# 0.0000     249524
# 5.0000     244913
# 4.0000     231891
# 6.0000     164651
# 7.0000         53
# 8.0000         53
# 9.0000         19
# Name: count, dtype: int64

# %%
# Replace the values with category
trip_category = yellow_df["trip_category"].replace(to_replace=[1, 2, 3, 4, 5, 6, 99], value=["Standard Rate", "JFK", "Newark", "Nassau or Westchester", "Negotiated Fare", "Group Ride", "Unknown"])
yellow_df["trip_category"] = trip_category

# %%
# Pick up and drop off locations
pick_up_borough = yellow_df["pulocationid"].map(taxi_zones_df["borough"])
pick_up_zone = yellow_df["pulocationid"].map(taxi_zones_df["zone"])
drop_off_borough = yellow_df["dolocationid"].map(taxi_zones_df["borough"])
drop_off_zone = yellow_df["dolocationid"].map(taxi_zones_df["zone"])

# Put into the dataframe
yellow_df.insert(loc=7, column="pick_up_borough", value=pick_up_borough)
yellow_df.insert(loc=8, column="pick_up_zone", value=pick_up_zone)
yellow_df.insert(loc=9, column="drop_off_borough", value=drop_off_borough)
yellow_df.insert(loc=10, column="drop_off_zone", value=drop_off_zone)

# Drop the columns
yellow_df.drop(columns=["pulocationid", "dolocationid", "vendorid"], inplace=True)

# %%
yellow_df["payment_type"] = yellow_df["payment_type"].replace(to_replace=[1, 2, 3, 4, 5, 6], value=["Credit Card", "Cash", "No Charge", "Dispute", "Unknown", "Voided Trip"])

# %%
yellow_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13836755 entries, 0 to 13836754
# Data columns (total 20 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   pickup_datetime        object
#  1   dropoff_datetime       object
#  2   passenger_count        float64
#  3   trip_miles             float64
#  4   trip_category          object
#  5   store_and_fwd_flag     object
#  6   pick_up_borough        object
#  7   pick_up_zone           object
#  8   drop_off_borough       object
#  9   drop_off_zone          object
#  10  payment_type           object
#  11  fare_amount            float64
#  12  extra                  float64
#  13  mta_tax                float64
#  14  tips                   float64
#  15  tolls                  float64
#  16  improvement_surcharge  float64
#  17  total_amount           float64
#  18  congestion_surcharge   float64
#  19  airport_fee            float64
# dtypes: float64(11), object(9)
# memory usage: 2.2+ GB

# %%
yellow_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
yellow_df.head()
# Out:
#        pickup_datetime     dropoff_datetime  passenger_count  trip_miles  \
# 0  2020-01-12 03:00:14  2020-01-12 03:10:18           1.0000      3.4000
# 1  2020-01-15 18:39:38  2020-01-15 18:50:17           1.0000      2.0100
# 2  2020-01-30 07:34:31  2020-01-30 07:48:24           1.0000      1.8800
# 3  2020-01-20 17:16:38  2020-01-20 17:23:34           2.0000      1.5400
# 4  2020-01-14 11:48:39  2020-01-14 12:03:40           1.0000      2.4000
#
#    trip_category store_and_fwd_flag pick_up_borough  \
# 0  Standard Rate                  N       Manhattan
# 1  Standard Rate                  N       Manhattan
# 2  Standard Rate                  N       Manhattan
# 3  Standard Rate                  N       Manhattan
# 4  Standard Rate                  N       Manhattan
#
#                     pick_up_zone drop_off_borough        drop_off_zone  \
# 0           TriBeCa/Civic Center        Manhattan         East Village
# 1  Meatpacking/West Village West        Manhattan         Clinton East
# 2                Lenox Hill West        Manhattan  Lincoln Square East
# 3                   Clinton East        Manhattan  Lincoln Square East
# 4                 Midtown Center        Manhattan       Yorkville West
#
#   payment_type  fare_amount  extra  mta_tax   tips  tolls  \
# 0  Credit Card      12.0000 0.5000   0.5000 3.1600 0.0000
# 1  Credit Card       9.5000 1.0000   0.5000 2.7600 0.0000
# 2  Credit Card      10.5000 0.0000   0.5000 2.7600 0.0000
# 3  Credit Card       7.0000 1.0000   0.5000 2.2600 0.0000
# 4  Credit Card      11.5000 2.5000   0.5000 2.9600 0.0000
#
#    improvement_surcharge  total_amount  congestion_surcharge  airport_fee
# 0                 0.3000       18.9600                2.5000       0.0000
# 1                 0.3000       16.5600                2.5000       0.0000
# 2                 0.3000       16.5600                2.5000       0.0000
# 3                 0.3000       13.5600                2.5000       0.0000
# 4                 0.3000       17.7600                2.5000       0.0000

# %%
yellow_df.describe()
# Out:
#        passenger_count    trip_miles     fare_amount         extra  \
# count    13073455.0000 13836755.0000   13836755.0000 13836755.0000
# mean            1.3910        5.2884          6.1314        1.1944
# std             0.9662      534.2129      35860.2324        1.5148
# min             0.0000      -29.0600 -133391414.0000      -39.1700
# 25%             1.0000        1.0500          7.2000        0.0000
# 50%             1.0000        1.8000         11.0000        0.5000
# 75%             1.0000        3.3500         17.7000        2.5000
# max             9.0000   351613.3600     429496.7200       90.0600
#
#             mta_tax           tips         tolls  improvement_surcharge  \
# count 13836755.0000  13836755.0000 13836755.0000          13836755.0000
# mean         0.4882        12.3619        0.4654                 0.5566
# std          0.0993     35860.0243        1.9561                 0.3584
# min         -0.5000      -333.3200     -114.2000                -1.0000
# 25%          0.5000         0.0000        0.0000                 0.3000
# 50%          0.5000         2.1500        0.0000                 0.3000
# 75%          0.5000         3.5000        0.0000                 1.0000
# max         42.1700 133391363.5300      700.1700                 1.0000
#
#        total_amount  congestion_surcharge   airport_fee
# count 13836755.0000         13836755.0000 13836755.0000
# mean        22.8663                2.1306        0.0810
# std        117.2293                0.9295        0.3495
# min      -1000.0000               -2.5000       -1.7500
# 25%         12.7400                2.5000        0.0000
# 50%         17.1600                2.5000        0.0000
# 75%         25.0000                2.5000        0.0000
# max     429562.2500                3.0000        1.7500

# %%
yellow_df.to_csv("data/Yellow_Trip_Data_Clean.csv", index=False)

# %%
pd.read_csv("data/Yellow_Trip_Data_Clean.csv")
# Out:
#               pickup_datetime     dropoff_datetime  passenger_count  \
# 0         2020-01-12 03:00:14  2020-01-12 03:10:18           1.0000
# 1         2020-01-15 18:39:38  2020-01-15 18:50:17           1.0000
# 2         2020-01-30 07:34:31  2020-01-30 07:48:24           1.0000
# 3         2020-01-20 17:16:38  2020-01-20 17:23:34           2.0000
# 4         2020-01-14 11:48:39  2020-01-14 12:03:40           1.0000
# ...                       ...                  ...              ...
# 13836750  2024-10-28 13:30:42  2024-10-28 13:52:28           2.0000
# 13836751  2024-10-30 22:20:28  2024-10-30 22:37:53           1.0000
# 13836752  2024-10-05 20:49:33  2024-10-05 21:09:48           1.0000
# 13836753  2024-10-30 09:27:50  2024-10-30 09:38:25           1.0000
# 13836754  2024-10-17 21:24:33  2024-10-17 21:43:55           2.0000
#
#           trip_miles  trip_category store_and_fwd_flag pick_up_borough  \
# 0             3.4000  Standard Rate                  N       Manhattan
# 1             2.0100  Standard Rate                  N       Manhattan
# 2             1.8800  Standard Rate                  N       Manhattan
# 3             1.5400  Standard Rate                  N       Manhattan
# 4             2.4000  Standard Rate                  N       Manhattan
# ...              ...            ...                ...             ...
# 13836750      5.3800  Standard Rate                  N       Manhattan
# 13836751      3.5800  Standard Rate                  N       Manhattan
# 13836752     10.4900  Standard Rate                  N       Manhattan
# 13836753      1.1000  Standard Rate                  N       Manhattan
# 13836754      8.8500  Standard Rate                  N          Queens
#
#                            pick_up_zone drop_off_borough  \
# 0                  TriBeCa/Civic Center        Manhattan
# 1         Meatpacking/West Village West        Manhattan
# 2                       Lenox Hill West        Manhattan
# 3                          Clinton East        Manhattan
# 4                        Midtown Center        Manhattan
# ...                                 ...              ...
# 13836750                   West Village        Manhattan
# 13836751                   West Village        Manhattan
# 13836752            Lincoln Square East            Bronx
# 13836753                 Yorkville West        Manhattan
# 13836754              LaGuardia Airport        Manhattan
#
#                                 drop_off_zone payment_type  fare_amount  \
# 0                                East Village  Credit Card      12.0000
# 1                                Clinton East  Credit Card       9.5000
# 2                         Lincoln Square East  Credit Card      10.5000
# 3                         Lincoln Square East  Credit Card       7.0000
# 4                              Yorkville West  Credit Card      11.5000
# ...                                       ...          ...          ...
# 13836750                     Manhattan Valley  Credit Card      26.8000
# 13836751                      Lenox Hill West  Credit Card      19.1000
# 13836752  Riverdale/North Riverdale/Fieldston  Credit Card      42.2000
# 13836753                      Lenox Hill East  Credit Card      10.0000
# 13836754                       Midtown Center  Credit Card      35.9000
#
#           extra  mta_tax    tips  tolls  improvement_surcharge  total_amount  \
# 0        0.5000   0.5000  3.1600 0.0000                 0.3000       18.9600
# 1        1.0000   0.5000  2.7600 0.0000                 0.3000       16.5600
# 2        0.0000   0.5000  2.7600 0.0000                 0.3000       16.5600
# 3        1.0000   0.5000  2.2600 0.0000                 0.3000       13.5600
# 4        2.5000   0.5000  2.9600 0.0000                 0.3000       17.7600
# ...         ...      ...     ...    ...                    ...           ...
# 13836750 0.0000   0.5000  7.7000 0.0000                 1.0000       38.5000
# 13836751 1.0000   0.5000  6.0300 0.0000                 1.0000       30.1300
# 13836752 1.0000   0.5000 10.0800 3.1800                 1.0000       60.4600
# 13836753 2.5000   0.5000  2.8000 0.0000                 1.0000       16.8000
# 13836754 6.0000   0.5000 13.2100 6.9400                 1.0000       67.8000
#
#           congestion_surcharge  airport_fee
# 0                       2.5000       0.0000
# 1                       2.5000       0.0000
# 2                       2.5000       0.0000
# 3                       2.5000       0.0000
# 4                       2.5000       0.0000
# ...                        ...          ...
# 13836750                2.5000       0.0000
# 13836751                2.5000       0.0000
# 13836752                2.5000       0.0000
# 13836753                2.5000       0.0000
# 13836754                2.5000       1.7500
#
# [13836755 rows x 20 columns]

# %% [markdown]
# # Green Taxi Dataset

# %%
# Replace column names
cols_replace = {
    "lpep_pickup_datetime": "pickup_datetime", "lpep_dropoff_datetime": "dropoff_datetime",
    "trip_distance": "trip_miles", "tolls_amount":  "tolls", "tip_amount": "tips", "ratecodeid": "trip_category"
    }
green_df.rename(columns=cols_replace, inplace=True)

# %%
green_df.isna().any()
# Out:
# vendorid                 False
# pickup_datetime          False
# dropoff_datetime         False
# store_and_fwd_flag        True
# trip_category             True
# pulocationid             False
# dolocationid             False
# passenger_count           True
# trip_miles               False
# fare_amount              False
# extra                    False
# mta_tax                  False
# tips                     False
# tolls                    False
# ehail_fee                 True
# improvement_surcharge    False
# total_amount             False
# payment_type              True
# trip_type                 True
# congestion_surcharge      True
# dtype: bool

# %%
green_df["congestion_surcharge"] = green_df["congestion_surcharge"].replace(np.nan, 0.00)

# %%
green_df["trip_category"].value_counts()
# Out:
# trip_category
# 1.0000     1716374
# 5.0000       75579
# 2.0000        5103
# 4.0000        1856
# 3.0000        1095
# 99.0000         96
# 6.0000          19
# Name: count, dtype: int64

# %%
green_df["payment_type"].value_counts()
# Out:
# payment_type
# 1.0000    1132550
# 2.0000     651926
# 3.0000      12129
# 4.0000       3469
# 5.0000         48
# Name: count, dtype: int64

# %%
# Replace the values with category
trip_category = green_df["trip_category"].replace(to_replace=[1, 2, 3, 4, 5, 6, 99], value=["Standard Rate", "JFK", "Newark", "Nassau or Westchester", "Negotiated Fare", "Group Ride", "Unknown"])
green_df["trip_category"] = trip_category

payment_type = green_df["payment_type"].replace(to_replace=[1, 2, 3, 4, 5, 6], value=["Credit Card", "Cash", "No Charge", "Dispute", "Unknown", "Voided Trip"])
green_df["payment_type"] = payment_type

# %%
# Pick up and drop off locations
pick_up_borough = green_df["pulocationid"].map(taxi_zones_df["borough"])
pick_up_zone = green_df["pulocationid"].map(taxi_zones_df["zone"])
drop_off_borough = green_df["dolocationid"].map(taxi_zones_df["borough"])
drop_off_zone = green_df["dolocationid"].map(taxi_zones_df["zone"])

# Put into the dataframe
green_df.insert(loc=5, column="pick_up_borough", value=pick_up_borough)
green_df.insert(loc=6, column="pick_up_zone", value=pick_up_zone)
green_df.insert(loc=7, column="drop_off_borough", value=drop_off_borough)
green_df.insert(loc=8, column="drop_off_zone", value=drop_off_zone)

# Drop the columns
green_df.drop(columns=["pulocationid", "dolocationid", "vendorid"], inplace=True)

# %%
green_df["payment_type"] = green_df["payment_type"].replace(to_replace=[1, 2, 3, 4, 5, 6], value=["Credit Card", "Cash", "No Charge", "Dispute", "Unknown", "Voided Trip"])

# %%
green_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
green_df.to_csv("data/Green_Trip_Data_Clean.csv", index=False)
